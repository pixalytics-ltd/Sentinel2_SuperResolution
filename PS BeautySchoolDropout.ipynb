# %% [markdown]
# Conducts all necessary preprocessing for PlanetScope (PS) Dove imagery files for the Super Resolution neural network (pulls mask, mosaics images, preps orbit data, and conducts normalization and downsampling).  NOTE: This notebook MUST be run after S2 Pyrite, because that notebook provides the Sentinel-2 input used in this notebook (s2_ref variable) for image co-registration.

# %%
import os
import json
import pandas as pd
import geopandas as gpd
import rasterio, rasterio.mask
from rasterio import Affine, merge
from rasterio.enums import Resampling
import numpy as np
import numpy.ma as ma
from arosics import COREG, DESHIFTER

# %%
# Knocks out all imagery for a single day.  THIS IS THE ONLY BLOCK YOU'LL NEED TO EDIT
homedir = r'/home/seadas/shared/marlisat/Training_Data'

# Set date for unique file names
date = 'Sep21_'

# Location of raw Dove images
# If NOT clipped: Set to folder ending with 'PSScene4Band'.  
# If clipped, set to folder 'files'
main_dir = os.path.join(homedir, 'ESA-AO/Planet/sep21south/PSScene4Band/')

# Sentinel-2 image to use for co-registration (NOT normalized, ...10_stack.tif or 10m_mosaic.tif)
s2_ref = os.path.join(homedir, 'ESA-AO/output/20210903_10m_mosaic.tif')

# Output folder (location of resulting preprocessed imagery -- recommend same location as S2 Pyrite output)
out_folder = os.path.join(homedir, 'ESA-AO/output/')

# Filepath to the shapefile of AOI
geom_fp = os.path.join(homedir, 'ESA-AO/Planet/sep21south/Sept21-Planet-AOI-49S.shp')
#geom_fp = '/home/sarahwegmueller/Documents/Casden_dev/Lakewood_OW/Full_OW_test_right.shp'

# %%
def file_setup(main_dir):
    '''Gets either the filenames, or folders for each image, depending whether clipping was used'''   
    if main_dir[-5:] == 'files':  #these are clipped images; file system differs
        os.chdir(main_dir)
        filenames = []

        files = os.listdir()
        
        # Get a list of image names:
        for name in files:
            if name.endswith("R_clip.tif"):
                file = name[:-23]
                filenames.append(file)
        
        return filenames
        
    else:
        os.chdir(main_dir)  #These are normally downloaded images

        # Get a list of image names:
        files = os.listdir()
        filenames = []
        for file in files:
            file = file + '_3B'
            filenames.append(file)
            
        # Get a list of image directories:
        new_wrk_dirs = []
        for file in files:
            new_dir = main_dir + '/' + file + '/analytic_sr_udm2'
            new_wrk_dirs.append(new_dir)
            
        return filenames, new_wrk_dirs

    
def create_ps_conf_mask(udm2_filename):
    '''Uses UDM2 file to write a binary mask: 1: clear with confidence > 75; 0: not clear)'''
    
    udm2_img = rasterio.open(udm2_filename)
    conf = udm2_img.read(7)
    mask = conf > 75
    mask_int = mask.astype('uint16')

    return mask_int

        
def rescale_image(scale, image, output_fp):
    '''Upsamples or downsamples, per scale input'''
        
    img = rasterio.open(image)
    profile = img.profile
    t = img.transform
    transform = Affine (t.a*scale, t.b, t.c, t.d, t.e*scale, t.f)
    height = int(img.height / scale)
    width = int(img.width / scale)
    profile.update(transform=transform, driver='GTiff', height=height, width=width)
    
    band_data = img.read([1, 2, 3, 4],
            out_shape=(4, height, width),
            resampling=Resampling.bilinear,
        )
    
    mask_data = img.read([5],
            out_shape=(1, height, width),
        )
    
    strip_data = img.read([6],
            out_shape=(1, height, width),
        )
    
    total_arr = np.concatenate((band_data, mask_data, strip_data), axis=0)
    
    with rasterio.open(output_fp, 'w', **profile) as dst:
        dst.write(total_arr)
    
def do_coreg(ref_img, tgt_img, reg_img_fp): #, mask_fp, reg_mask_fp):
    '''Conduct co-registration on PS clipped imagery using the NIR band -- assumed to be band 4 in images'''
    CR = COREG(ref_img, tgt_img, reg_img_fp,  #the string here is the output name -- can be adjusted
           fmt_out='GTIFF',
           r_b4match=4,  #using the NIR band because its the best one on the Doves
           s_b4match=4,
           ws=(200,200), #100,100
           nodata=(0,0),
           max_shift = 20.0, # Maximum shift allowed
          )

    CR.calculate_spatial_shifts()
    CR.correct_shifts()  # Corrects image and then write it to a file
    
    #DESHIFTER(mask_fp, CR.coreg_info, path_out=reg_mask_fp, fmt_out='GTIFF').correct_shifts()
    
def get_sat_gen(metadata_filepath):
    '''Get PS satellite generation from metadata''' 
    
    metadata = json.load(open(metadata_filepath))
    gen = metadata['properties']['instrument']
    sat_id = metadata['properties']['satellite_id']
    
    return gen, sat_id
    
def normalize_bands(image_fp, out_fp):
    '''Normalizes bands using the 1st and 99th percentile. 
    Assumes the mask is the last band unless mask_bool is given.'''
    
    norm_arrays = []
    img = rasterio.open(image_fp)

    # Get the full mask -- values to exclude when calc norm percentages
    mask = img.read(5)
    mask_bool = mask==0
    
    # Create a mask of the border area
    borders = img.read(1)
    borders_bool = borders == 0
        
    for num, band in enumerate(range(1, 5)):
        data = img.read(band)

        tmp = ma.masked_array(data, mask_bool)
        arr = np.zeros((np.shape(data)[0], np.shape(data)[1]), dtype=np.uint16)
        arr = ma.filled(tmp, 0)

        data_clean = arr[arr !=0]
        low = np.percentile(data_clean, 1)
        high = np.percentile(data_clean, 99)

        dif = high-low

        low_arr = np.full(arr.shape, low)
        dif_arr = np.full(arr.shape, dif)

        data_norm = (data - low_arr) / dif_arr

        data_norm_scaled = (data_norm+100) * 10000

        #new_bool = arr==0
        new_bool = data=0

        tmp2 = ma.masked_array(data_norm_scaled, new_bool)
        norm_arr = np.zeros((np.shape(data_norm)[0], np.shape(data_norm)[1]), dtype=np.uint16)
        norm_arr = ma.filled(tmp2, 0)
        
        tmp3 = ma.masked_array(norm_arr, borders_bool)
        norm_arr_final = np.zeros((np.shape(data_norm)[0], np.shape(data_norm)[1]), dtype=np.uint16)
        norm_arr_final = ma.filled(tmp3, 0)
        
        norm_arr_final.astype('uint16')
        
        if num == 0:
            with rasterio.open(out_fp, 'w', **img.profile) as dst:
                dst.write(norm_arr_final, 1)
        else:
            with rasterio.open(out_fp, 'r+', **img.profile) as dst:
                dst.write(norm_arr_final, num+1)
                
        norm_arr_final = None
                
    with rasterio.open(out_fp, 'r+', **img.profile) as dst:
                dst.write(mask, 5)


def append_strip_number(image_fp, num, out_fp):
    '''Appends a band made up of the num variable in place of valid pixels'''
    
    img = rasterio.open(image_fp)
    bands = img.read()
    ex_band = img.read(1)
    borders_bool = ex_band == 0
        
    strip_num = np.full((bands.shape[1], bands.shape[2]), num, dtype=np.uint16)
    
    tmp = ma.masked_array(strip_num, borders_bool)
    strip_final = np.zeros((ex_band.shape[0], ex_band.shape[1]), dtype=np.uint16)
    strip_final = ma.filled(tmp, 0)
    
    strip_final = np.expand_dims(strip_final, axis=0)

    full_array = np.concatenate((bands, strip_final), axis=0)
    
    profile = img.profile
    profile['count'] = 6
    
    with rasterio.open(out_fp, 'w',**profile) as dst:
        dst.write(full_array)

# %%
# Create dataframe to collect satellite id (for strip number) and mask percentage (mosaic hierarchy)

if main_dir[-5:] == 'files':
    filenames = file_setup(main_dir)
else: 
    filenames, new_wrk_dirs = file_setup(main_dir)       

df = pd.DataFrame(index=range(0, len(filenames)), columns=['img', 'sat_id'])

# %%
aoi = gpd.read_file(geom_fp)
geom = [aoi['geometry'].iloc[0]]

left = aoi.bounds.iloc[0][0]
bottom = aoi.bounds.iloc[0][1]
right = aoi.bounds.iloc[0][2]
top = aoi.bounds.iloc[0][3]


if main_dir[-5:] == 'files':  
    files_to_remove_after_mosaic = []   
    
    for num, filename in enumerate(filenames):
        print('This is file: ', filename)
        
        #Get sat_id
        meta = filename[:-3] + '_metadata.json'
        gen, sat_id = get_sat_gen(meta)

        # Create mask
        udm2_fp = filename + '_udm2_clip.tif'
        mask = create_ps_conf_mask(udm2_fp)
        mask = np.expand_dims(mask, axis=0)
        
        # Append the mask to the stack
        org_sr = rasterio.open(filename + '_AnalyticMS_SR_clip.tif')
        org_bands = org_sr.read()
        
        profile = org_sr.profile
        profile['count'] = 5
        
        band_mask_stack = np.concatenate((org_bands, mask))
        
        org_bands=None
        mask=None
                
        stack_fp = filename + 'withMask.tif'
        files_to_remove_after_mosaic.append(stack_fp)
        
        with rasterio.open(stack_fp, 'w', **profile) as dst:
            dst.write(band_mask_stack)
        
        band_mask_stack = None
            
        # Populate the dataframe
        df['img'].iloc[num] = stack_fp
        df['sat_id'].iloc[num] = sat_id

    # Mosaic images from the same satellite by order of least masking
    sats = df['sat_id'].unique()

    mosaic_order_df = pd.DataFrame(index=range(0, len(df['sat_id'].unique())), columns=['mosaic', 'masked_ratio']) 
    
    for num, sat in enumerate(sats):
        working_df = df[df['sat_id']==sat]

        # Get the images from the same satellite 
        fps = list(working_df['img'].values)
        # Loop throught and check exist as some files may have moved since previously run
        for f in fps:
            if not os.path.exists(f):
                fps.remove(f)
        
        if len(fps) > 1: #more than one image     
            
            # Mosaic them, and then crop to AOI
            mosaic_array, mosaic_transform = rasterio.merge.merge(fps, method='first')
            
            # Crop the image to the AOI
            cropped_arr, cropped_transform = rasterio.mask.mask(mosaic_array, geom, crop=True)
            mosaic_array = None

            # Get the masked ratio
            mask = cropped_arr[4,:,:]
            ratio = (len(mask[mask==0])) / len(mask.flatten())
            mask = None
            
            # Use the satellite ID to create a unique filename
            sat_id = working_df['sat_id'].unique()[0]
            
            # Write the mosaic
            profile = rasterio.open(fps[0]).profile
            profile['transform'] = cropped_transform
            profile['height'] = cropped_arr.shape[1]
            profile['width'] = cropped_arr.shape[2]

            dst_path = sat_id + '_mosaic.tif'

            with rasterio.open(dst_path, 'w', **profile) as dst:
                dst.write(cropped_arr)
                
            cropped_arr = None

            # Register the mosaic to the Sentinel-2 image
            reg_img_fp = out_folder + dst_path[:-4] + '_reg.tif'
            do_coreg(s2_ref, dst_path, reg_img_fp)
            
            os.remove(dst_path)
            
            # Normalize bands to 1st and 99th percentile         
            norm_fp = reg_img_fp[:-4] + 'norm.tif'
            normalize_bands(reg_img_fp, norm_fp)
            
            os.remove(reg_img_fp)
            
            # Record the masked percentage
            mosaic_order_df['mosaic'].iloc[num] = norm_fp
            mosaic_order_df['masked_ratio'].iloc[num] = ratio
            
        else:
            image_fp = working_df['img'].iloc[0]
            
            # Crop the image to the AOI
            img = rasterio.open(image_fp)
            cropped_arr, transform = rasterio.mask.mask(img, geom, crop=True)

            # Write to file
            cropped_image = sat_id + '_cropped_image.tif'
            
            # Update profile
            profile = img.profile
            profile['transform'] = transform
            profile['height'] = cropped_arr.shape[1]
            profile['width'] = cropped_arr.shape[2]

            # Write the image
            with rasterio.open(cropped_image, 'w', **profile) as dst:
                dst.write(cropped_arr)

            # Clear some memory
            cropped_arr = None
            
            # Register the image to the Sentinel-2 image
            reg_img_fp = out_folder + cropped_image[:-4] + '_reg.tif'
            do_coreg(s2_ref, cropped_image, reg_img_fp)
            
            # Normalize bands to 1st and 99th percentile         
            norm_fp = reg_img_fp[:-4] + 'norm.tif'
            normalize_bands(reg_img_fp, norm_fp)
            
            os.remove(cropped_image)
            os.remove(reg_img_fp)
            
            # Find percent masked
            mask_band = rasterio.open(norm_fp).read(5)
            ratio = (len(mask_band[mask_band==0])) / len(mask_band.flatten())
            
            mosaic_order_df['mosaic'].iloc[num] = norm_fp
            mosaic_order_df['masked_ratio'].iloc[num] = ratio           

    for f in files_to_remove_after_mosaic:
        os.remove(f)

    files_to_remove_after_mosaic = []  
    
else:
    files_to_remove_after_mosaic = []
    
    csvfile = os.path.join(out_folder, "df_sats.csv")
    if os.path.exists(csvfile):
        df = pd.read_csv(csvfile)
        print("Loaded data frame from {}".format(csvfile))
        
    else:
        for num, folder in enumerate(new_wrk_dirs):
            os.chdir(folder)
            filename = filenames[num]
            print(filename)
            
            stack_fp = filename + 'withMask.tif'
            
            # Check metadata for satellite generation 
            os.chdir(os.path.abspath(os.path.join(folder, os.pardir)))
            meta = [f for f in os.listdir() if f.endswith('.json')]
            gen, sat_id = get_sat_gen(meta[0])

            os.chdir(folder)

            if not os.path.exists(stack_fp):

                # Create mask
                clip = ''
                udm2_fp = filename + '_udm2.tif'
                mask_out = filename + '_udm2_mask.tif'
                if not os.path.exists(udm2_fp):
                    udm2_fp = filename + '_udm2_clip.tif'
                    if os.path.exists(udm2_fp):
                        print("Using clipped mask")
                        clip = '_clip'
                    else:
                        print("Missing mask, so skipping")
                        continue
                    
                mask = create_ps_conf_mask(udm2_fp)
                mask = np.expand_dims(mask, axis=0)

                # Append the mask to the stack
                org_sr = rasterio.open(filename + '_AnalyticMS_SR' + clip + '.tif')
                org_bands = org_sr.read()

                profile = org_sr.profile
                profile['count'] = 5

                band_mask_stack = np.concatenate((org_bands, mask))

                org_bands=None
                mask=None


                print("Writing {}".format(stack_fp))
                with rasterio.open(stack_fp, 'w', **profile) as dst:
                    dst.write(band_mask_stack)

                band_mask_stack = None

            # Populate the dataframe
            df['img'].iloc[num] = os.path.join(folder, stack_fp)
            df['sat_id'].iloc[num] = sat_id

            files_to_remove_after_mosaic.append(os.path.join(folder, stack_fp))

            
        # Save data frame information
        df.to_csv(csvfile, index = False)
        print("Wrote data frame to {}".format(csvfile))
        
        
    # Mosaic images from the same satellite by order of least masking
    sats = df['sat_id'].unique() 
        
    mosaic_order_df = pd.DataFrame(index=range(0, len(df['sat_id'].unique())), columns=['mosaic', 'masked_ratio']) 
    
    for num, sat in enumerate(sats):
        os.chdir(out_folder)
        working_df = df[df['sat_id']==sat]
        
        if len(working_df) > 1: #more than one image
            # Use the satellite ID to create a unique filename
            sat_id = working_df['sat_id'].unique()[0]
            dst_path = sat_id + '_mosaic.tif'
            csvfile = os.path.join(out_folder, 'df_' + sat_id + '.csv')
            reg_img_fp = os.path.join(out_folder, dst_path[:-4] + '_reg.tif')
        elif len(working_df) == 1:
            image_fp = working_df['img'].iloc[0]
            cropped_image = image_fp[:-4]+ sat + '_cropped_image.tif'
            csvfile = os.path.join(out_folder, 'df_' + sat + '.csv')
            reg_img_fp = cropped_image[:-4] + '_reg.tif'
        else:
            mosaic_order_df['mosaic'].iloc[num] = 'None'
            mosaic_order_df['masked_ratio'].iloc[num] = 0.0
            continue
            
        norm_fp = reg_img_fp[:-4] + 'norm.tif'
        print("Looking for {} and {}".format(norm_fp, csvfile))

        if not os.path.exists(csvfile): # already generated
            # Get the images from the same satellite 
            fps = list(working_df['img'].values)
            for f in fps:
                if not os.path.exists(f):
                    fps.remove(f)
            if len(fps) > 1: # more than one image
                
                # Mosaic them, and crop to AOI
                mosaic_array, mosaic_transform = rasterio.merge.merge(fps, 
                                                                      #bounds=(left, bottom, right, top),
                                                                      method='first')            

                # Get the masked ratio
                mask = mosaic_array[4,:,:]
                ratio = (len(mask[mask==0])) / len(mask.flatten())
                mask = None

                # Write the mosaic
                profile = rasterio.open(fps[0]).profile
                profile['transform'] = mosaic_transform
                profile['height'] = mosaic_array.shape[1]
                profile['width'] = mosaic_array.shape[2]

                with rasterio.open(dst_path, 'w', **profile) as dst:
                    dst.write(mosaic_array)

                mosaic_array = None
                
                try:
                    # Register the mosaic to the Sentinel-2 image
                    do_coreg(s2_ref, dst_path, reg_img_fp)
                except:
                    print("Failed to co-register, so skipping")
                    os.remove(dst_path)
                    mosaic_order_df['mosaic'].iloc[num] = 'None'
                    mosaic_order_df['masked_ratio'].iloc[num] = 0.0
                    continue

                os.remove(dst_path)

                # Normalize bands to 1st and 99th percentile         
                normalize_bands(reg_img_fp, norm_fp)

                os.remove(reg_img_fp)
            
                # Record the masked percentage
                mosaic_order_df['mosaic'].iloc[num] = norm_fp
                mosaic_order_df['masked_ratio'].iloc[num] = ratio
                       
            else:

                # Crop the image to the AOI
                img = rasterio.open(image_fp)
                try:
                    cropped_arr, transform = rasterio.mask.mask(img, geom, crop=True)
                except:
                    print("Cropping to AOI failed, assume outside of AOI, so skipping")
                    mosaic_order_df['mosaic'].iloc[num] = 'None'
                    mosaic_order_df['masked_ratio'].iloc[num] = 0.0
                    continue

                # Write to file

                # Update profile
                profile = img.profile
                profile['transform'] = transform
                profile['height'] = cropped_arr.shape[1]
                profile['width'] = cropped_arr.shape[2]

                # Write the image
                with rasterio.open(cropped_image, 'w', **profile) as dst:
                    dst.write(cropped_arr)

                # Clear some memory
                cropped_arr = None

                try:
                    # Register the image to the Sentinel-2 image
                    do_coreg(s2_ref, cropped_image, reg_img_fp)
                except:
                    print("Failed to co-register, so skipping")
                    mosaic_order_df['mosaic'].iloc[num] = 'None'
                    mosaic_order_df['masked_ratio'].iloc[num] = 0.0
                    continue

                # Normalize bands to 1st and 99th percentile         
                normalize_bands(reg_img_fp, norm_fp)

                os.remove(reg_img_fp)

                # Find percent masked
                mask_band = rasterio.open(norm_fp).read(5)
                ratio = (len(mask_band[mask_band==0])) / len(mask_band.flatten())

                mosaic_order_df['mosaic'].iloc[num] = norm_fp
                mosaic_order_df['masked_ratio'].iloc[num] = ratio   
                
            # Save df_sat
            df_sat = pd.DataFrame(index=range(0, 1), columns=['mosaic', 'masked_ratio'])
            df_sat['mosaic']= norm_fp
            df_sat['masked_ratio'] = ratio
            # Save data frame information
            df_sat.to_csv(csvfile, index = False)
            print("Wrote data frame to {}".format(csvfile))
            del df_sat

            
        else:
            # Read df_info
            df_sat = pd.read_csv(csvfile)
            print("Loaded data frame from {}".format(csvfile))
            mosaic_order_df['mosaic'].iloc[num] = df_sat['mosaic'].values[0]
            mosaic_order_df['masked_ratio'].iloc[num] = df_sat['masked_ratio'].values[0]  

    print("Mosaic data frame: ",mosaic_order_df)
    #for f in files_to_remove_after_mosaic:
    #    os.remove(f)

    files_to_remove_after_mosaic = []  

# Mosaic files
dst_path = out_folder + date + 'PS_mosaic.tif'
img_resamp = dst_path[:-4] + '_resamp.tif'
if not os.path.exists(img_resamp):
    # Get mosaic order   
    df2 = mosaic_order_df.sort_values(by='masked_ratio').copy()

    # Create list of images from df; order to be mosaicked (images with least masking are considered best)
    img_order = list(df2['mosaic'].values)

    # Get strip numbers; Append a 6th band with strip number
    df2['strip_num'] = range(1, len(df2)+1) # set strip numbers
    for row in range(len(df2)):  # Add the strip number band
        image_fp = df2['mosaic'].iloc[row]
        num = df2['strip_num'].iloc[row]
        out_fp = image_fp[:-4] + '_strip.tif'
        if os.path.exists(image_fp):
            print("Including {} {}".format(row,image_fp))
            append_strip_number(image_fp, num, out_fp)
        else:
            print("Could not find {} {}, skipping".format(row,image_fp))
        files_to_remove_after_mosaic.append(out_fp)

    for num, img in enumerate(img_order): # Adjust names in the image order
        img_order[num] = img[:-4] + '_strip.tif'

    # Create full mosaic ... FINALLY
    datasets = []

    for img in img_order:
        if os.path.exists(img):
            image = rasterio.open(img)
            datasets.append(image)

    print("Mosaicing Planet strips")
    mosaic_array, mosaic_transform = rasterio.merge.merge(datasets, method='first')

    profile = datasets[0].profile
    profile['transform'] = mosaic_transform
    profile['height'] = mosaic_array.shape[1]
    profile['width'] = mosaic_array.shape[2]

    with rasterio.open(dst_path, 'w', **profile) as dst:
        dst.write(mosaic_array)
    
    # Clear some memory
    mosaic_array = None
    datasets = None
    
    # Clear working files:
    #for file in files_to_remove_after_mosaic:
    #    os.remove(file)
    #for file in df2['mosaic'].values:
    #    os.remove(file)

    # Resample mosaic to 2.5m resolution
    scale = 2.5/3 
    rescale_image(scale, dst_path, img_resamp)

    #os.remove(dst_path)
# Out:
# Loaded data frame from /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_sats.csv
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/2449_mosaic_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2449.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for image to be shifted:
# 	(308054.0533055526, 9118866.442672908, 350636.4685341129, 9163437.657782407)
# Matching window position (X,Y): 329361.69024843175/9141141.402883912
# No clear match found yet. Jumping to iteration 2...
# input shifts:  0 -22
# No clear match found yet. Jumping to iteration 3...
# input shifts:  0 -10
# No clear match found yet. Jumping to iteration 4...
# input shifts:  -2 0
# No clear match found yet. Jumping to iteration 5...
# input shifts:  11 0
# Failed to co-register, so skipping
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/2420_mosaic_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2420.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for image to be shifted:
# 	(206761.1984331644, 9113335.580378566, 249150.46643964434, 9157764.062393138)
# Matching window position (X,Y): 227935.91354697003/9135564.168916853
# No clear match found yet. Jumping to iteration 2...
# input shifts:  -14 19
# No clear match found yet. Jumping to iteration 3...
# input shifts:  -64 -53
# No clear match found yet. Jumping to iteration 4...
# input shifts:  12 -10
# No clear match found yet. Jumping to iteration 5...
# input shifts:  7 -34
# Failed to co-register, so skipping
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/245c_mosaic_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_245c.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for image to be shifted:
# 	(231400.75941023152, 9121773.186036672, 273888.81999109086, 9166255.370555075)
# Matching window position (X,Y): 252714.86817507763/9144023.873482816
# No clear match found yet. Jumping to iteration 2...
# input shifts:  56 -24
# No clear match found yet. Jumping to iteration 3...
# input shifts:  -14 -21
# No clear match found yet. Jumping to iteration 4...
# input shifts:  36 -27
# No clear match found yet. Jumping to iteration 5...
# input shifts:  8 29
# Failed to co-register, so skipping
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210901_021740_81_2431/analytic_sr_udm2/20210901_021740_81_2431_3BwithMask2431_cropped_image_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2431.csv
# Loaded data frame from /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2431.csv
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/2264_mosaic_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2264.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:02
# Bounding box of calculated footprint for image to be shifted:
# 	(806015.0813028711, 9132472.67833692, 828361.5551378076, 9174370.308647139)
# Failed to co-register, so skipping
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210901_030029_08_2413/analytic_sr_udm2/20210901_030029_08_2413_3BwithMask2413_cropped_image_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2413.csv
# Loaded data frame from /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2413.csv
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/240a_mosaic_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_240a.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for image to be shifted:
# 	(270996.7209075755, 9114997.442430506, 313313.2118189513, 9159655.361363927)
# Matching window position (X,Y): 292207.0016909274/9137331.364371352
# No clear match found yet. Jumping to iteration 2...
# input shifts:  -2 0
# No clear match found yet. Jumping to iteration 3...
# input shifts:  -16 -47
# No clear match found yet. Jumping to iteration 4...
# input shifts:  23 16
# No clear match found yet. Jumping to iteration 5...
# input shifts:  -6 0
# Failed to co-register, so skipping
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210901_030629_47_2405/analytic_sr_udm2/20210901_030629_47_2405_3BwithMask2405_cropped_image_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2405.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:02
# Bounding box of calculated footprint for image to be shifted:
# 	(196210.35854950006, 9114685.750215089, 235181.34618285112, 9142828.659030624)
# Matching window position (X,Y): 216628.4580505472/9128832.563891347
# No clear match found yet. Jumping to iteration 2...
# input shifts:  -19 0
# No clear match found yet. Jumping to iteration 3...
# input shifts:  -4 -59
# No clear match found yet. Jumping to iteration 4...
# input shifts:  -7 6
# No clear match found yet. Jumping to iteration 5...
# input shifts:  37 5
# Failed to co-register, so skipping
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210902_021020_80_2439/analytic_sr_udm2/20210902_021020_80_2439_3BwithMask2439_cropped_image_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2439.csv
# Loaded data frame from /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_2439.csv
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210902_024713_65_105c/analytic_sr_udm2/20210902_024713_65_105c_3BwithMask105c_cropped_image_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_105c.csv
# Loaded data frame from /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_105c.csv
# Looking for /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/1057_mosaic_regnorm.tif and /home/seadas/shared/marlisat/Training_Data/ESA-AO/output/df_1057.csv
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:03
# Bounding box of calculated footprint for reference image:
# 	(199980.0, 9097455.41020167, 369330.0, 9181463.059691235)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:02
# Bounding box of calculated footprint for image to be shifted:
# 	(238601.00792297738, 9130431.511066755, 268589.7731514068, 9162301.604860155)
# Matching window position (X,Y): 253580.32479388305/9146403.32918238
# No clear match found yet. Jumping to iteration 2...
# input shifts:  -3 6
# No clear match found yet. Jumping to iteration 3...
# input shifts:  39 25
# No clear match found yet. Jumping to iteration 4...
# input shifts:  0 -20
# No clear match found yet. Jumping to iteration 5...
# input shifts:  53 -39
# Failed to co-register, so skipping
# Mosaic data frame:                                                 mosaic masked_ratio
# 0                                                None          0.0
# 1                                                None          0.0
# 2                                                None          0.0
# 3   /home/seadas/shared/marlisat/Training_Data/ESA...     0.618457
# 4                                                None          0.0
# 5   /home/seadas/shared/marlisat/Training_Data/ESA...      0.37318
# 6                                                None          0.0
# 7                                                None          0.0
# 8   /home/seadas/shared/marlisat/Training_Data/ESA...     0.743624
# 9                                                None          0.0
# 10  /home/seadas/shared/marlisat/Training_Data/ESA...     0.481967
# 11                                               None          0.0
# Could not find 0 None, skipping
# Could not find 1 None, skipping
# Could not find 2 None, skipping
# Could not find 3 None, skipping
# Could not find 4 None, skipping
# Could not find 5 None, skipping
# Could not find 6 None, skipping
# Could not find 7 None, skipping
# Including 8 /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210901_030029_08_2413/analytic_sr_udm2/20210901_030029_08_2413_3BwithMask2413_cropped_image_regnorm.tif
# Including 9 /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210902_024713_65_105c/analytic_sr_udm2/20210902_024713_65_105c_3BwithMask105c_cropped_image_regnorm.tif
# Including 10 /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210901_021740_81_2431/analytic_sr_udm2/20210901_021740_81_2431_3BwithMask2431_cropped_image_regnorm.tif
# Including 11 /home/seadas/shared/marlisat/Training_Data/ESA-AO/Planet/sep21south/PSScene4Band//20210902_021020_80_2439/analytic_sr_udm2/20210902_021020_80_2439_3BwithMask2439_cropped_image_regnorm.tif

# %%
#### Downsample images for NN training #####

# %%
def rescale_dove_image(scale, image, output_fp):
    '''Upsamples or downsamples, per scale input'''
        
    img = rasterio.open(image)
    profile = img.profile
    
    t = img.transform
    transform = Affine (t.a*scale, t.b, t.c, t.d, t.e*scale, t.f)
    height = int(img.height / scale)
    width = int(img.width / scale)
    profile.update(transform=transform, driver='GTiff', height=height, width=width)
    
    vis_bands = img.read([1, 2, 3, 4], out_shape=(4, height, width), resampling=Resampling.cubic)
    aux_bands = img.read([5, 6], out_shape=(2, height, width), resampling=Resampling.nearest)
    
    new_bands = np.concatenate((vis_bands, aux_bands), axis=0)
    vis_bands = None
    aux_bands = None
    
    with rasterio.open(output_fp, 'w', **profile) as dst:
        dst.write(new_bands)

# %%
# PS --> 10m
ps10m = out_folder + 'dove_10m.tif'
rescale_dove_image(4, img_resamp, ps10m)

# PS --> 20m
ps20m = out_folder + 'dove_20m.tif'
rescale_dove_image(8, img_resamp, ps20m)

# %%
# Pull the orbits (strips) out of the mosaic

images_to_pull_orbits = [img_resamp, ps10m, ps20m]

corresponding_out_fps = [date+'Dove_mosaic.tif', date+'Dove_10m_mosaic.tif', date+'Dove_20m_mosaic.tif']
orbit_fps = [date+'Dove_Orbits.tif', date+'Dove_Orbits_10m.tif', date+'Dove_Orbits_20m.tif']

for num, mos in enumerate(images_to_pull_orbits):
    
    img = rasterio.open(mos)
    bands = img.read([1, 2, 3, 4, 5])
    bands.shape

    profile = img.profile
    profile['count'] = 5

    new_fp = out_folder + corresponding_out_fps[num]

    # Rewrite image without orbits
    with rasterio.open(new_fp, 'w', **profile) as dst:
        dst.write(bands)

    # Read in orbits and write to separate image (prep for one-hot encoding)
    orbits = img.read(6)

    profile = img.profile
    profile['count'] = 1

    orbit_fp = out_folder + orbit_fps[num]

    with rasterio.open(orbit_fp, 'w', **profile) as dst:
        dst.write(orbits, 1)

# %%
# Remove working files
#for file in images_to_pull_orbits:
#    os.remove(file)
